# %% [markdown]
# <a href="https://colab.research.google.com/github/cornel-kim/samples/blob/DataScience/Lesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
school = pd.read_csv("http://modcom.co.ke/data2020/datasets/school.csv")
school
# Out:
#        ids        bday  enrolldate  ... CommuteTime  SleepTime StudyTime
# 0    43783   3/22/1995         NaN  ...         NaN        7.0       1.0
# 1    20278    1/1/1995         NaN  ...         NaN        5.0       2.0
# 2    20389  12/31/1994         NaN  ...         NaN        8.0       7.0
# 3    22820   12/1/1994         NaN  ...         NaN        2.0       6.0
# 4    24559  11/10/1994         NaN  ...         NaN        7.0       3.0
# ..     ...         ...         ...  ...         ...        ...       ...
# 430  34021   7/18/1987  1-Aug-2011  ...        18.0        1.0      10.0
# 431  40697   4/29/1987  1-Aug-2011  ...        26.0        6.0      15.0
# 432  34272         NaN  1-Aug-2011  ...        29.0        6.0      10.0
# 433  33628         NaN  1-Aug-2011  ...        14.0        4.0      10.0
# 434  39298         NaN  1-Aug-2011  ...        27.0        2.0      10.0
#
# [435 rows x 23 columns]

# %%
#check empty fields
print(school.isnull().sum())
# Out:
# ids               0
# bday              8
# enrolldate       29
# expgradate       29
# Rank             29
# Major           159
# Gender            9
# Athlete           0
# Height           27
# Weight           59
# Smoking          24
# Sprint           61
# MileMinDur       43
# English          26
# Reading          10
# Math             13
# Writing          31
# State            27
# LiveOnCampus     21
# HowCommute      188
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64

# %%
#get subset to use
subset1 = school[['Rank', 'Major', 'Gender','Writing', 'Math', 'Reading']]
subset1.tail(100)
# Out:
#      Rank              Major  Gender  Writing   Math  Reading
# 335   3.0        Philosophey     0.0    77.09  60.05    66.57
# 336   3.0                NaN     NaN    75.24  61.72    91.35
# 337   3.0                NaN     0.0    75.77  63.70      NaN
# 338   3.0   military history     0.0    83.99  60.88    73.73
# 339   3.0  Special Education     1.0    91.78  69.35    83.69
# ..    ...                ...     ...      ...    ...      ...
# 430   4.0         accounting     1.0      NaN  65.31    84.99
# 431   4.0                NaN     0.0    82.67  70.25    86.87
# 432   4.0            nursing     0.0    81.87  58.16    85.76
# 433   4.0            Nursing     1.0    79.35  66.84    85.97
# 434   4.0                NaN     1.0    75.23  60.24    77.24
#
# [100 rows x 6 columns]

# %%
subset1.isnull().sum()
# Out:
# Rank        29
# Major      159
# Gender       9
# Writing     31
# Math        13
# Reading     10
# dtype: int64

# %%
#Replacing empty field with the a number
subset1['Gender'].fillna(2, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
subset1.tail(100)
# Out:
#      Rank              Major  Gender  Writing   Math  Reading
# 335   3.0        Philosophey     0.0    77.09  60.05    66.57
# 336   3.0                NaN     2.0    75.24  61.72    91.35
# 337   3.0                NaN     0.0    75.77  63.70      NaN
# 338   3.0   military history     0.0    83.99  60.88    73.73
# 339   3.0  Special Education     1.0    91.78  69.35    83.69
# ..    ...                ...     ...      ...    ...      ...
# 430   4.0         accounting     1.0      NaN  65.31    84.99
# 431   4.0                NaN     0.0    82.67  70.25    86.87
# 432   4.0            nursing     0.0    81.87  58.16    85.76
# 433   4.0            Nursing     1.0    79.35  66.84    85.97
# 434   4.0                NaN     1.0    75.23  60.24    77.24
#
# [100 rows x 6 columns]

# %%
#convert number representation to words
subset1['Gender'].replace({0:'Male', 1:'Female', 2:'Unknown'}, inplace=True)
subset1.tail(100)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#      Rank              Major   Gender  Writing   Math  Reading
# 335   3.0        Philosophey     Male    77.09  60.05    66.57
# 336   3.0                NaN  Unknown    75.24  61.72    91.35
# 337   3.0                NaN     Male    75.77  63.70      NaN
# 338   3.0   military history     Male    83.99  60.88    73.73
# 339   3.0  Special Education   Female    91.78  69.35    83.69
# ..    ...                ...      ...      ...    ...      ...
# 430   4.0         accounting   Female      NaN  65.31    84.99
# 431   4.0                NaN     Male    82.67  70.25    86.87
# 432   4.0            nursing     Male    81.87  58.16    85.76
# ...

# %%
import matplotlib.pyplot as plt
x, y = plt.subplots()
subset1.groupby('Gender').size().plot(kind='pie', autopct="%1.1f%%")
y.set_title("Gender representation")
y.set_xlabel("")
y.set_ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
subset1.isnull().sum()
# Out:
# Rank        29
# Major      159
# Gender       0
# Writing     31
# Math        13
# Reading     10
# dtype: int64
